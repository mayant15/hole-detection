# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('Hole_Detection_Test_Data.txt', sep=' ', names=['X', 'Y', 'Z'])

# %%
px.scatter_3d(df, x='X', y='Y', z='Z')

# %%
px.
# Out:
#              X         Y        Z
# 0      58.7167 -148.2170 -40.3922
# 1      58.6926 -148.0260 -40.3188
# 2      58.5866 -147.8640 -40.2546
# 3      58.7033 -147.8700 -40.2664
# 4      58.9011 -147.9390 -40.3229
# ...        ...       ...      ...
# 53310  68.6696  -82.1109 -17.0031
# 53311  68.3915  -82.2267 -16.9975
# 53312  68.4265  -82.2134 -16.9952
# 53313  68.4727  -82.1934 -16.9980
# 53314  68.6562  -82.1193 -16.9959
#
# [53315 rows x 3 columns]
